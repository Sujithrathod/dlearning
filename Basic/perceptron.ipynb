# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    "cgpa" : [8.14,6.17,8.27,6.88,7.52],
    "resume_score" : [6.54,5.17,8.86,7.27,7.30],
    "placed" : [1,0,1,1,1]
})
df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.54       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(x = df["cgpa"],y = df["resume_score"],hue =df["placed"])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()
p.fit(x,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[5.74, 9.49]])

# %%
p.intercept_
# Out:
# array([-2.])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.values,y.values,clf=p,legend=2)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
